# %%
import os
import importlib
import sys
import matplotlib.pyplot as plt

sys.path.append('/Users/aeshef/Documents/GitHub/kursach/pys/improved_pipeline')

import grid_search
importlib.reload(grid_search)
from grid_search import run_grid_search_pipeline

import short_selling_support
importlib.reload(short_selling_support)
from short_selling_support import run_short_selling_pipeline

import honest_backtest
importlib.reload(honest_backtest)
from honest_backtest import HonestBacktester

# %%
def run_improved_pipeline(
    data_file="/Users/aeshef/Documents/GitHub/kursach/data/df.csv",
    output_dir="/Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline",
    risk_free_rate=0.075,
    run_grid_search=True,
    run_honest_backtest=True,
    run_short_selling=True
):
    """
    Запускает улучшенный пайплайн с grid search, честным бэктестом и поддержкой шортов
    """
    os.makedirs(output_dir, exist_ok=True)
    
    results = {}
    
    # 1. Grid Search для нахождения оптимальных параметров
    if run_grid_search:
        grid_search_dir = os.path.join(output_dir, 'grid_search')
        os.makedirs(grid_search_dir, exist_ok=True)
        
        print("Запуск Grid Search для поиска оптимальных параметров...")
        grid_results, best_params = run_grid_search_pipeline(
            data_file=data_file,
            output_dir=grid_search_dir,
            training_period=('2024-01-01', '2024-12-31')
        )
        
        results['grid_search'] = {
            'best_params': best_params,
            'results_file': os.path.join(grid_search_dir, 'grid_search_results.csv')
        }
    
    # 2. Честный бэктест на будущий период
    if run_honest_backtest:
        honest_backtest_dir = os.path.join(output_dir, 'honest_backtest')
        os.makedirs(honest_backtest_dir, exist_ok=True)
        
        print("Запуск честного бэктеста на будущем периоде...")
        
        # Используем лучшие параметры из Grid Search, если доступны
        best_params_file = os.path.join(output_dir, 'grid_search/best_params.json') \
            if run_grid_search and os.path.exists(os.path.join(output_dir, 'grid_search/best_params.json')) \
            else None
        
        # ИЗМЕНЕНО: используем класс HonestBacktester вместо функции run_honest_backtest
        backtester = HonestBacktester(
            data_file=data_file,
            best_params_file=best_params_file,
            train_period=('2024-01-01', '2024-12-31'),
            test_period=('2025-01-01', '2025-06-30'),
            output_dir=honest_backtest_dir,
            risk_free_rate=risk_free_rate
        )
        backtest_report = backtester.run()
        
        results['honest_backtest'] = {
            'report': backtest_report,
            'report_file': os.path.join(honest_backtest_dir, 'honest_backtest_report.md')
        }
    
    # 3. Стратегия с короткими позициями
    if run_short_selling:
        short_selling_dir = os.path.join(output_dir, 'short_selling')
        os.makedirs(short_selling_dir, exist_ok=True)
        
        print("Запуск стратегии с короткими позициями...")
        short_selling_results = run_short_selling_pipeline(
            data_file=data_file,
            output_dir=short_selling_dir,
            risk_free_rate=risk_free_rate,
            period=('2024-01-01', '2025-04-15')
        )
        
        results['short_selling'] = {
            'results': short_selling_results,
            'results_dir': short_selling_dir
        }
    
    # Сохраняем итоговый отчет
    with open(os.path.join(output_dir, 'pipeline_report.md'), 'w') as f:
        f.write("# Отчет о выполнении улучшенного пайплайна\n\n")
        
        if run_grid_search and 'grid_search' in results:
            f.write("## Grid Search\n")
            f.write(f"* Лучшие параметры сохранены в: {results['grid_search']['results_file']}\n")
            
            # Если есть доступ к лучшим параметрам, выводим их
            if 'best_params' in results['grid_search']:
                best = results['grid_search']['best_params']
                f.write("* Лучшие параметры:\n")
                for k, v in best.items():
                    if k.startswith('signal_') or k.startswith('portfolio_'):
                        f.write(f"  - {k}: {v}\n")
            f.write("\n")
        
        if run_honest_backtest and 'honest_backtest' in results:
            f.write("## Честный бэктест\n")
            f.write(f"* Полный отчет: {results['honest_backtest']['report_file']}\n")
            
            # Если есть доступ к отчету, выводим основные метрики
            if 'report' in results['honest_backtest']:
                report = results['honest_backtest']['report']
                if 'test_metrics' in report:
                    metrics = report['test_metrics']
                    f.write("* Ключевые метрики тестового периода:\n")
                    f.write(f"  - Годовая доходность: {metrics['annual_return']*100:.2f}%\n")
                    f.write(f"  - Коэффициент Шарпа: {metrics['sharpe_ratio']:.2f}\n")
                    f.write(f"  - Максимальная просадка: {metrics['max_drawdown']*100:.2f}%\n")
            f.write("\n")
        
        if run_short_selling and 'short_selling' in results:
            f.write("## Стратегия с короткими позициями\n")
            f.write(f"* Результаты сохранены в: {results['short_selling']['results_dir']}\n")
            
            # Безопасная проверка наличия метрик бэктеста
            if 'results' in results['short_selling']:
                backtest_results = results['short_selling']['results'].get('backtest')
                if backtest_results is not None and isinstance(backtest_results, dict) and 'metrics' in backtest_results:
                    metrics = backtest_results['metrics']
                    f.write("* Ключевые метрики стратегии с шортами:\n")
                    f.write(f"  - Годовая доходность: {metrics['annual_return']*100:.2f}%\n")
                    f.write(f"  - Коэффициент Шарпа: {metrics['sharpe_ratio']:.2f}\n")
                    f.write(f"  - Максимальная просадка: {metrics['max_drawdown']*100:.2f}%\n")
                else:
                    f.write("* Метрики бэктеста недоступны. Возможные причины:\n")
                    f.write("  - Недостаточно данных для расчета\n")
                    f.write("  - Проблемы с совместимостью сигналов и цен\n")
                    
                # Отчет о портфеле всегда должен быть доступен
                if 'portfolio' in results['short_selling']['results']:
                    portfolio = results['short_selling']['results']['portfolio']
                    if portfolio:
                        f.write("* Состав портфеля с короткими позициями:\n")
                        for ticker, weight in portfolio.get('weights', {}).items():
                            if abs(weight) >= 0.05:  # Показываем только значимые позиции
                                f.write(f"  - {ticker}: {weight*100:.1f}%\n")
    
    print(f"Улучшенный пайплайн завершен. Результаты сохранены в: {output_dir}")
    return results

# %%
run_improved_pipeline(run_grid_search=False)
# Out:
# 2025-04-24 18:56:54 - HonestBacktester - INFO - HonestBacktester initialized
# 2025-04-24 18:56:54 - HonestBacktester - INFO - Загрузка данных из /Users/aeshef/Documents/GitHub/kursach/data/df.csv
# Запуск честного бэктеста на будущем периоде...
# 2025-04-24 18:56:54 - HonestBacktester - INFO - Данные разделены: 5823 строк для обучения, 1648 строк для тестирования
# 2025-04-24 18:56:55 - HonestBacktester - INFO - Использование параметров по умолчанию
# 2025-04-24 18:56:55 - HonestBacktester - INFO - Запуск генерации сигналов на тренировочных данных
# 2025-04-24 18:56:55,660 - signal_generator - INFO - Запуск пайплайна генерации торговых сигналов
# 2025-04-24 18:56:55,661 - signal_generator - INFO - Загрузка данных из /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_data_20250424_185654.csv
# 2025-04-24 18:56:55,788 - signal_generator - INFO - Загружено 5823 строк данных
# 2025-04-24 18:56:55,789 - signal_generator - INFO - Расчет композитного скора
# 2025-04-24 18:56:55,793 - signal_generator - INFO - Технический скор рассчитан на основе 6 индикаторов
# 2025-04-24 18:56:55,796 - signal_generator - INFO - Сентимент-скор рассчитан на основе 5 индикаторов
# 2025-04-24 18:56:55,796 - signal_generator - INFO - Расчет фундаментального скора
# 2025-04-24 18:56:55,797 - signal_generator - INFO - Загрузка фундаментальных данных для 16 тикеров
# 2025-04-24 18:56:55,800 - signal_generator - INFO - Загружены данные AFKS за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:56:55,802 - signal_generator - INFO - Загружены данные AFKS за 2024: 37 показателей, 0 отсутствует
# 2025-04-24 18:56:55,802 - signal_generator - INFO - Загружены данные ALRS за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:56:55,804 - signal_generator - INFO - Загружены данные ALRS за 2024: 37 показателей, 0 отсутствует
# 2025-04-24 18:56:55,804 - signal_generator - INFO - Загружены данные GAZP за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:56:55,805 - signal_generator - INFO - Загружены данные GAZP за 2024: 0 показателей, 37 отсутствует
# 2025-04-24 18:56:55,806 - signal_generator - INFO - Загружены данные GMKN за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:56:55,807 - signal_generator - INFO - Загружены данные GMKN за 2024: 37 показателей, 0 отсутствует
# 2025-04-24 18:56:55,808 - signal_generator - INFO - Загружены данные LKOH за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:56:55,809 - signal_generator - INFO - Загружены данные LKOH за 2024: 37 показателей, 0 отсутствует
# 2025-04-24 18:56:55,810 - signal_generator - INFO - Загружены данные MAGN за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:56:55,811 - signal_generator - INFO - Загружены данные MAGN за 2024: 34 показателей, 3 отсутствует
# 2025-04-24 18:56:55,812 - signal_generator - INFO - Загружены данные MTSS за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:56:55,813 - signal_generator - INFO - Загружены данные MTSS за 2024: 37 показателей, 0 отсутствует
# 2025-04-24 18:56:55,813 - signal_generator - INFO - Загружены данные MVID за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:56:55,814 - signal_generator - INFO - Загружены данные MVID за 2024: 0 показателей, 37 отсутствует
# 2025-04-24 18:56:55,815 - signal_generator - INFO - Загружены данные NVTK за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:56:55,816 - signal_generator - INFO - Загружены данные NVTK за 2024: 37 показателей, 0 отсутствует
# 2025-04-24 18:56:55,817 - signal_generator - INFO - Загружены данные PHOR за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:56:55,818 - signal_generator - INFO - Загружены данные PHOR за 2024: 37 показателей, 0 отсутствует
# 2025-04-24 18:56:55,820 - signal_generator - INFO - Загружены данные ROSN за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:56:55,821 - signal_generator - INFO - Загружены данные ROSN за 2024: 35 показателей, 2 отсутствует
# 2025-04-24 18:56:55,822 - signal_generator - INFO - Загружены данные RUAL за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:56:55,823 - signal_generator - INFO - Загружены данные RUAL за 2024: 37 показателей, 0 отсутствует
# 2025-04-24 18:56:55,824 - signal_generator - INFO - Загружены данные SBER за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:56:55,825 - signal_generator - INFO - Загружены данные SBER за 2024: 13 показателей, 24 отсутствует
# 2025-04-24 18:56:55,825 - signal_generator - INFO - Загружены данные SIBN за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:56:55,826 - signal_generator - INFO - Загружены данные SIBN за 2024: 37 показателей, 0 отсутствует
# 2025-04-24 18:56:55,827 - signal_generator - INFO - Загружены данные SNGS за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:56:55,828 - signal_generator - INFO - Загружены данные SNGS за 2024: 0 показателей, 37 отсутствует
# 2025-04-24 18:56:55,829 - signal_generator - INFO - Загружены данные TATN за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:56:55,830 - signal_generator - INFO - Загружены данные TATN за 2024: 37 показателей, 0 отсутствует
# 2025-04-24 18:56:55,865 - signal_generator - INFO - Доступность фундаментальных показателей:
# 2025-04-24 18:56:55,865 - signal_generator - INFO -   2023 - EPS, руб: 100.0% компаний
# 2025-04-24 18:56:55,866 - signal_generator - INFO -   2023 - EV, млрд руб: 100.0% компаний
# 2025-04-24 18:56:55,866 - signal_generator - INFO -   2023 - P/E: 100.0% компаний
# 2025-04-24 18:56:55,867 - signal_generator - INFO -   2023 - ROA, %: 100.0% компаний
# 2025-04-24 18:56:55,867 - signal_generator - INFO -   2023 - ROE, %: 100.0% компаний
# 2025-04-24 18:56:55,867 - signal_generator - INFO -   2023 - Див доход, ао, %: 100.0% компаний
# 2025-04-24 18:56:55,868 - signal_generator - INFO -   2023 - Дивиденды/прибыль, %: 100.0% компаний
# 2025-04-24 18:56:55,868 - signal_generator - INFO -   2023 - Капитализация, млрд руб: 100.0% компаний
# 2025-04-24 18:56:55,868 - signal_generator - INFO -   2023 - Опер. расходы, млрд руб: 100.0% компаний
# 2025-04-24 18:56:55,869 - signal_generator - INFO -   2023 - Цена акции ао, руб: 100.0% компаний
# 2025-04-24 18:56:55,869 - signal_generator - INFO -   2023 - Число акций ао, млн: 100.0% компаний
# 2025-04-24 18:56:55,869 - signal_generator - INFO -   2023 - Чистая прибыль, млрд руб: 100.0% компаний
# 2025-04-24 18:56:55,870 - signal_generator - INFO -   2023 - Чистый долг, млрд руб: 100.0% компаний
# 2025-04-24 18:56:55,874 - signal_generator - INFO -   2024 - BV/акцию, руб: 75.0% компаний
# 2025-04-24 18:56:55,874 - signal_generator - INFO -   2024 - CAPEX, млрд руб: 75.0% компаний
# 2025-04-24 18:56:55,874 - signal_generator - INFO -   2024 - CAPEX/Выручка, %: 75.0% компаний
# 2025-04-24 18:56:55,875 - signal_generator - INFO -   2024 - EBITDA, млрд руб: 75.0% компаний
# 2025-04-24 18:56:55,875 - signal_generator - INFO -   2024 - EPS, руб: 81.2% компаний
# 2025-04-24 18:56:55,875 - signal_generator - INFO -   2024 - EV, млрд руб: 81.2% компаний
# 2025-04-24 18:56:55,876 - signal_generator - INFO -   2024 - EV/EBITDA: 75.0% компаний
# 2025-04-24 18:56:55,876 - signal_generator - INFO -   2024 - FCF, млрд руб: 75.0% компаний
# 2025-04-24 18:56:55,876 - signal_generator - INFO -   2024 - FCF/акцию, руб: 75.0% компаний
# 2025-04-24 18:56:55,877 - signal_generator - INFO -   2024 - P/BV: 75.0% компаний
# 2025-04-24 18:56:55,877 - signal_generator - INFO -   2024 - P/E: 81.2% компаний
# 2025-04-24 18:56:55,877 - signal_generator - INFO -   2024 - P/FCF: 75.0% компаний
# 2025-04-24 18:56:55,878 - signal_generator - INFO -   2024 - P/S: 75.0% компаний
# 2025-04-24 18:56:55,883 - signal_generator - INFO -   2024 - R&D/CAPEX, %: 75.0% компаний
# 2025-04-24 18:56:55,883 - signal_generator - INFO -   2024 - ROA, %: 81.2% компаний
# 2025-04-24 18:56:55,884 - signal_generator - INFO -   2024 - ROE, %: 81.2% компаний
# 2025-04-24 18:56:55,884 - signal_generator - INFO -   2024 - Активы, млрд руб: 75.0% компаний
# 2025-04-24 18:56:55,884 - signal_generator - INFO -   2024 - Амортизация, млрд руб: 68.8% компаний
# 2025-04-24 18:56:55,885 - signal_generator - INFO -   2024 - Баланс стоимость, млрд руб: 75.0% компаний
# 2025-04-24 18:56:55,885 - signal_generator - INFO -   2024 - Выручка, млрд руб: 75.0% компаний
# 2025-04-24 18:56:55,885 - signal_generator - INFO -   2024 - Див доход, ао, %: 81.2% компаний
# 2025-04-24 18:56:55,885 - signal_generator - INFO -   2024 - Дивиденды/прибыль, %: 81.2% компаний
# 2025-04-24 18:56:55,886 - signal_generator - INFO -   2024 - Долг, млрд руб: 68.8% компаний
# 2025-04-24 18:56:55,886 - signal_generator - INFO -   2024 - Долг/EBITDA: 68.8% компаний
# 2025-04-24 18:56:55,886 - signal_generator - INFO -   2024 - Доходность FCF, %: 75.0% компаний
# 2025-04-24 18:56:55,886 - signal_generator - INFO -   2024 - Капитализация, млрд руб: 81.2% компаний
# 2025-04-24 18:56:55,887 - signal_generator - INFO -   2024 - Наличность, млрд руб: 75.0% компаний
# 2025-04-24 18:56:55,887 - signal_generator - INFO -   2024 - Опер. расходы, млрд руб: 81.2% компаний
# 2025-04-24 18:56:55,887 - signal_generator - INFO -   2024 - Опер.денежный поток, млрд руб: 75.0% компаний
# 2025-04-24 18:56:55,887 - signal_generator - INFO -   2024 - Операционная прибыль, млрд руб: 75.0% компаний
# 2025-04-24 18:56:55,888 - signal_generator - INFO -   2024 - Рентаб EBITDA, %: 75.0% компаний
# 2025-04-24 18:56:55,888 - signal_generator - INFO -   2024 - Цена акции ао, руб: 81.2% компаний
# 2025-04-24 18:56:55,888 - signal_generator - INFO -   2024 - Число акций ао, млн: 81.2% компаний
# 2025-04-24 18:56:55,888 - signal_generator - INFO -   2024 - Чистая прибыль, млрд руб: 81.2% компаний
# 2025-04-24 18:56:55,888 - signal_generator - INFO -   2024 - Чистая рентаб, %: 75.0% компаний
# 2025-04-24 18:56:55,889 - signal_generator - INFO -   2024 - Чистые активы, млрд руб: 75.0% компаний
# 2025-04-24 18:56:55,889 - signal_generator - INFO -   2024 - Чистый долг, млрд руб: 68.8% компаний
# 2025-04-24 18:56:56,525 - signal_generator - INFO - Фундаментальные скоры по тикерам:
# 2025-04-24 18:56:56,526 - signal_generator - INFO -   AFKS: 2023: -0.174
# 2025-04-24 18:56:56,526 - signal_generator - INFO -   ALRS: 2023: 0.003
# 2025-04-24 18:56:56,526 - signal_generator - INFO -   GAZP: 2023: -0.326
# 2025-04-24 18:56:56,527 - signal_generator - INFO -   GMKN: 2023: -0.048
# 2025-04-24 18:56:56,527 - signal_generator - INFO -   LKOH: 2023: 0.281
# 2025-04-24 18:56:56,527 - signal_generator - INFO -   MAGN: 2023: -0.041
# 2025-04-24 18:56:56,527 - signal_generator - INFO -   MTSS: 2023: -0.039
# 2025-04-24 18:56:56,528 - signal_generator - INFO -   MVID: 2023: -0.026
# 2025-04-24 18:56:56,528 - signal_generator - INFO -   NVTK: 2023: 0.011
# 2025-04-24 18:56:56,528 - signal_generator - INFO -   PHOR: 2023: 0.173
# 2025-04-24 18:56:56,529 - signal_generator - INFO -   ROSN: 2023: 0.047
# 2025-04-24 18:56:56,529 - signal_generator - INFO -   RUAL: 2023: -0.343
# 2025-04-24 18:56:56,529 - signal_generator - INFO -   SBER: 2023: 0.148
# 2025-04-24 18:56:56,529 - signal_generator - INFO -   SIBN: 2023: 0.085
# 2025-04-24 18:56:56,530 - signal_generator - INFO -   SNGS: 2023: 0.160
# 2025-04-24 18:56:56,530 - signal_generator - INFO -   TATN: 2023: 0.082
# 2025-04-24 18:56:56,531 - signal_generator - INFO - Композитный скор рассчитан
# 2025-04-24 18:56:56,543 - signal_generator - INFO - Сгенерировано сигналов: Buy - 495, Hold - 4959, Sell - 369
# 2025-04-24 18:56:56,798 - signal_generator - INFO - Создан shortlist из 5823 записей (топ 30.0%)
# 2025-04-24 18:56:56,802 - signal_generator - INFO - Шортлист сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/shortlists/shortlist_20241231.csv
# 2025-04-24 18:56:56,803 - signal_generator - INFO - Актуальный шортлист сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/results.csv
# 2025-04-24 18:56:56,803 - signal_generator - INFO - Визуализация графиков котировок с торговыми сигналами
# 2025-04-24 18:56:57,073 - signal_generator - INFO - График сигналов для AFKS сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/AFKS/signals.png
# 2025-04-24 18:56:57,334 - signal_generator - INFO - График сигналов для ALRS сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/ALRS/signals.png
# 2025-04-24 18:56:57,596 - signal_generator - INFO - График сигналов для GAZP сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/GAZP/signals.png
# 2025-04-24 18:56:57,859 - signal_generator - INFO - График сигналов для GMKN сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/GMKN/signals.png
# 2025-04-24 18:56:58,161 - signal_generator - INFO - График сигналов для LKOH сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/LKOH/signals.png
# 2025-04-24 18:56:58,421 - signal_generator - INFO - График сигналов для MAGN сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/MAGN/signals.png
# 2025-04-24 18:56:58,686 - signal_generator - INFO - График сигналов для MTSS сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/MTSS/signals.png
# 2025-04-24 18:56:58,944 - signal_generator - INFO - График сигналов для MVID сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/MVID/signals.png
# 2025-04-24 18:56:59,204 - signal_generator - INFO - График сигналов для NVTK сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/NVTK/signals.png
# 2025-04-24 18:56:59,462 - signal_generator - INFO - График сигналов для PHOR сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/PHOR/signals.png
# 2025-04-24 18:56:59,728 - signal_generator - INFO - График сигналов для ROSN сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/ROSN/signals.png
# 2025-04-24 18:56:59,992 - signal_generator - INFO - График сигналов для RUAL сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/RUAL/signals.png
# 2025-04-24 18:57:00,255 - signal_generator - INFO - График сигналов для SBER сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/SBER/signals.png
# 2025-04-24 18:57:00,515 - signal_generator - INFO - График сигналов для SIBN сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/SIBN/signals.png
# 2025-04-24 18:57:00,782 - signal_generator - INFO - График сигналов для SNGS сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/SNGS/signals.png
# 2025-04-24 18:57:01,046 - signal_generator - INFO - График сигналов для TATN сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/TATN/signals.png
# 2025-04-24 18:57:01,046 - signal_generator - INFO - Визуализация компонентов композитного скора
# 2025-04-24 18:57:01,490 - signal_generator - INFO - График скоров для AFKS сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/AFKS/scores.png
# 2025-04-24 18:57:01,927 - signal_generator - INFO - График скоров для ALRS сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/ALRS/scores.png
# 2025-04-24 18:57:02,378 - signal_generator - INFO - График скоров для GAZP сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/GAZP/scores.png
# 2025-04-24 18:57:02,829 - signal_generator - INFO - График скоров для GMKN сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/GMKN/scores.png
# 2025-04-24 18:57:03,298 - signal_generator - INFO - График скоров для LKOH сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/LKOH/scores.png
# 2025-04-24 18:57:03,734 - signal_generator - INFO - График скоров для MAGN сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/MAGN/scores.png
# 2025-04-24 18:57:04,176 - signal_generator - INFO - График скоров для MTSS сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/MTSS/scores.png
# 2025-04-24 18:57:04,616 - signal_generator - INFO - График скоров для MVID сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/MVID/scores.png
# 2025-04-24 18:57:05,062 - signal_generator - INFO - График скоров для NVTK сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/NVTK/scores.png
# 2025-04-24 18:57:05,499 - signal_generator - INFO - График скоров для PHOR сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/PHOR/scores.png
# 2025-04-24 18:57:05,947 - signal_generator - INFO - График скоров для ROSN сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/ROSN/scores.png
# 2025-04-24 18:57:06,383 - signal_generator - INFO - График скоров для RUAL сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/RUAL/scores.png
# 2025-04-24 18:57:06,825 - signal_generator - INFO - График скоров для SBER сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/SBER/scores.png
# 2025-04-24 18:57:07,645 - signal_generator - INFO - График скоров для SIBN сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/SIBN/scores.png
# 2025-04-24 18:57:08,092 - signal_generator - INFO - График скоров для SNGS сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/SNGS/scores.png
# 2025-04-24 18:57:08,536 - signal_generator - INFO - График скоров для TATN сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/TATN/scores.png
# 2025-04-24 18:57:09,453 - signal_generator - INFO - Исторические сигналы сохранены в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results/signals/signals_20250424.csv
# 2025-04-24 18:57:10,355 - signal_generator - INFO - Полные результаты сохранены в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_signals_20250424_185654.csv
# 2025-04-24 18:57:10,355 - signal_generator - INFO - Пайплайн выполнен за 14.69 секунд
# 2025-04-24 18:57:10,355 - signal_generator - INFO - Обработано 5823 строк данных
# 2025-04-24 18:57:10,356 - signal_generator - INFO - Обработано 16 тикеров
# 2025-04-24 18:57:10,357 - signal_generator - INFO - Создано сигналов: Buy - 495, Hold - 4959, Sell - 369
# 2025-04-24 18:57:10,357 - signal_generator - INFO - В шортлист включено 5823 записей
# 2025-04-24 18:57:10,357 - signal_generator - INFO - Все результаты сохранены в каталоге: /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_results
# 2025-04-24 18:57:10 - HonestBacktester - INFO - Запуск оптимизации портфеля на тренировочных данных
# 2025-04-24 18:57:10,359 - portfolio_optimizer - INFO - Запуск пайплайна оптимизации портфеля
# 2025-04-24 18:57:10,360 - portfolio_optimizer - INFO - Загрузка данных из /Users/aeshef/Documents/GitHub/kursach/data/signals.csv
# 2025-04-24 18:57:10,513 - portfolio_optimizer - INFO - Загружено 7471 строк данных
# 2025-04-24 18:57:10,513 - portfolio_optimizer - INFO - Подготовка данных доходностей для оптимизации
# 2025-04-24 18:57:10,517 - portfolio_optimizer - INFO - Отфильтровано 7030 строк по shortlist и сигналам
# 2025-04-24 18:57:10,535 - portfolio_optimizer - INFO - Рассчитаны доходности для 16 тикеров
# 2025-04-24 18:57:10,536 - portfolio_optimizer - INFO - Запуск оптимизации портфеля для 16 активов
# 2025-04-24 18:57:10,567 - portfolio_optimizer - INFO - Оптимизация успешно завершена
# 2025-04-24 18:57:10,567 - portfolio_optimizer - INFO - Расчет итогового портфеля с долей безрисковых активов 30.0%
# 2025-04-24 18:57:10,568 - portfolio_optimizer - INFO - Ожидаемая доходность портфеля: 3.10%, волатильность: 14.42%, Шарп: -0.30
# 2025-04-24 18:57:10,569 - portfolio_optimizer - INFO - Создание визуализации портфеля
# 2025-04-24 18:57:10,606 - portfolio_optimizer - INFO - График весов сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_portfolio/portfolio/portfolio_weights_pie.png
# 2025-04-24 18:57:10,607 - portfolio_optimizer - INFO - Результаты сохранены в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/train_portfolio/portfolio
# 2025-04-24 18:57:10 - HonestBacktester - INFO - Запуск генерации сигналов на тестовых данных
# 2025-04-24 18:57:10,608 - signal_generator - INFO - Запуск пайплайна генерации торговых сигналов
# 2025-04-24 18:57:10,608 - signal_generator - INFO - Загрузка данных из /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_data_20250424_185654.csv
# 2025-04-24 18:57:10,652 - signal_generator - INFO - Загружено 1648 строк данных
# 2025-04-24 18:57:10,652 - signal_generator - INFO - Расчет композитного скора
# 2025-04-24 18:57:10,655 - signal_generator - INFO - Технический скор рассчитан на основе 6 индикаторов
# 2025-04-24 18:57:10,658 - signal_generator - INFO - Сентимент-скор рассчитан на основе 5 индикаторов
# 2025-04-24 18:57:10,658 - signal_generator - INFO - Расчет фундаментального скора
# 2025-04-24 18:57:10,658 - signal_generator - INFO - Загрузка фундаментальных данных для 16 тикеров
# 2025-04-24 18:57:10,660 - signal_generator - INFO - Загружены данные AFKS за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:57:10,661 - signal_generator - INFO - Загружены данные AFKS за 2024: 37 показателей, 0 отсутствует
# 2025-04-24 18:57:10,662 - signal_generator - INFO - Загружены данные ALRS за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:57:10,663 - signal_generator - INFO - Загружены данные ALRS за 2024: 37 показателей, 0 отсутствует
# 2025-04-24 18:57:10,664 - signal_generator - INFO - Загружены данные GAZP за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:57:10,665 - signal_generator - INFO - Загружены данные GAZP за 2024: 0 показателей, 37 отсутствует
# 2025-04-24 18:57:10,666 - signal_generator - INFO - Загружены данные GMKN за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:57:10,667 - signal_generator - INFO - Загружены данные GMKN за 2024: 37 показателей, 0 отсутствует
# 2025-04-24 18:57:10,668 - signal_generator - INFO - Загружены данные LKOH за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:57:10,669 - signal_generator - INFO - Загружены данные LKOH за 2024: 37 показателей, 0 отсутствует
# 2025-04-24 18:57:10,670 - signal_generator - INFO - Загружены данные MAGN за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:57:10,671 - signal_generator - INFO - Загружены данные MAGN за 2024: 34 показателей, 3 отсутствует
# 2025-04-24 18:57:10,672 - signal_generator - INFO - Загружены данные MTSS за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:57:10,673 - signal_generator - INFO - Загружены данные MTSS за 2024: 37 показателей, 0 отсутствует
# 2025-04-24 18:57:10,674 - signal_generator - INFO - Загружены данные MVID за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:57:10,675 - signal_generator - INFO - Загружены данные MVID за 2024: 0 показателей, 37 отсутствует
# 2025-04-24 18:57:10,676 - signal_generator - INFO - Загружены данные NVTK за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:57:10,677 - signal_generator - INFO - Загружены данные NVTK за 2024: 37 показателей, 0 отсутствует
# 2025-04-24 18:57:10,677 - signal_generator - INFO - Загружены данные PHOR за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:57:10,678 - signal_generator - INFO - Загружены данные PHOR за 2024: 37 показателей, 0 отсутствует
# 2025-04-24 18:57:10,679 - signal_generator - INFO - Загружены данные ROSN за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:57:10,680 - signal_generator - INFO - Загружены данные ROSN за 2024: 35 показателей, 2 отсутствует
# 2025-04-24 18:57:10,681 - signal_generator - INFO - Загружены данные RUAL за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:57:10,682 - signal_generator - INFO - Загружены данные RUAL за 2024: 37 показателей, 0 отсутствует
# 2025-04-24 18:57:10,683 - signal_generator - INFO - Загружены данные SBER за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:57:10,684 - signal_generator - INFO - Загружены данные SBER за 2024: 13 показателей, 24 отсутствует
# 2025-04-24 18:57:10,685 - signal_generator - INFO - Загружены данные SIBN за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:57:10,686 - signal_generator - INFO - Загружены данные SIBN за 2024: 37 показателей, 0 отсутствует
# 2025-04-24 18:57:10,687 - signal_generator - INFO - Загружены данные SNGS за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:57:10,688 - signal_generator - INFO - Загружены данные SNGS за 2024: 0 показателей, 37 отсутствует
# 2025-04-24 18:57:10,689 - signal_generator - INFO - Загружены данные TATN за 2023: 13 показателей, 0 отсутствует
# 2025-04-24 18:57:10,690 - signal_generator - INFO - Загружены данные TATN за 2024: 37 показателей, 0 отсутствует
# 2025-04-24 18:57:10,723 - signal_generator - INFO - Доступность фундаментальных показателей:
# 2025-04-24 18:57:10,723 - signal_generator - INFO -   2023 - EPS, руб: 100.0% компаний
# 2025-04-24 18:57:10,723 - signal_generator - INFO -   2023 - EV, млрд руб: 100.0% компаний
# 2025-04-24 18:57:10,724 - signal_generator - INFO -   2023 - P/E: 100.0% компаний
# 2025-04-24 18:57:10,724 - signal_generator - INFO -   2023 - ROA, %: 100.0% компаний
# 2025-04-24 18:57:10,724 - signal_generator - INFO -   2023 - ROE, %: 100.0% компаний
# 2025-04-24 18:57:10,725 - signal_generator - INFO -   2023 - Див доход, ао, %: 100.0% компаний
# 2025-04-24 18:57:10,725 - signal_generator - INFO -   2023 - Дивиденды/прибыль, %: 100.0% компаний
# 2025-04-24 18:57:10,725 - signal_generator - INFO -   2023 - Капитализация, млрд руб: 100.0% компаний
# 2025-04-24 18:57:10,725 - signal_generator - INFO -   2023 - Опер. расходы, млрд руб: 100.0% компаний
# 2025-04-24 18:57:10,726 - signal_generator - INFO -   2023 - Цена акции ао, руб: 100.0% компаний
# 2025-04-24 18:57:10,726 - signal_generator - INFO -   2023 - Число акций ао, млн: 100.0% компаний
# 2025-04-24 18:57:10,726 - signal_generator - INFO -   2023 - Чистая прибыль, млрд руб: 100.0% компаний
# 2025-04-24 18:57:10,726 - signal_generator - INFO -   2023 - Чистый долг, млрд руб: 100.0% компаний
# 2025-04-24 18:57:10,727 - signal_generator - INFO -   2024 - BV/акцию, руб: 75.0% компаний
# 2025-04-24 18:57:10,727 - signal_generator - INFO -   2024 - CAPEX, млрд руб: 75.0% компаний
# 2025-04-24 18:57:10,727 - signal_generator - INFO -   2024 - CAPEX/Выручка, %: 75.0% компаний
# 2025-04-24 18:57:10,727 - signal_generator - INFO -   2024 - EBITDA, млрд руб: 75.0% компаний
# 2025-04-24 18:57:10,727 - signal_generator - INFO -   2024 - EPS, руб: 81.2% компаний
# 2025-04-24 18:57:10,728 - signal_generator - INFO -   2024 - EV, млрд руб: 81.2% компаний
# 2025-04-24 18:57:10,728 - signal_generator - INFO -   2024 - EV/EBITDA: 75.0% компаний
# 2025-04-24 18:57:10,728 - signal_generator - INFO -   2024 - FCF, млрд руб: 75.0% компаний
# 2025-04-24 18:57:10,728 - signal_generator - INFO -   2024 - FCF/акцию, руб: 75.0% компаний
# 2025-04-24 18:57:10,728 - signal_generator - INFO -   2024 - P/BV: 75.0% компаний
# 2025-04-24 18:57:10,729 - signal_generator - INFO -   2024 - P/E: 81.2% компаний
# 2025-04-24 18:57:10,729 - signal_generator - INFO -   2024 - P/FCF: 75.0% компаний
# 2025-04-24 18:57:10,729 - signal_generator - INFO -   2024 - P/S: 75.0% компаний
# 2025-04-24 18:57:10,729 - signal_generator - INFO -   2024 - R&D/CAPEX, %: 75.0% компаний
# 2025-04-24 18:57:10,730 - signal_generator - INFO -   2024 - ROA, %: 81.2% компаний
# 2025-04-24 18:57:10,730 - signal_generator - INFO -   2024 - ROE, %: 81.2% компаний
# 2025-04-24 18:57:10,730 - signal_generator - INFO -   2024 - Активы, млрд руб: 75.0% компаний
# 2025-04-24 18:57:10,730 - signal_generator - INFO -   2024 - Амортизация, млрд руб: 68.8% компаний
# 2025-04-24 18:57:10,730 - signal_generator - INFO -   2024 - Баланс стоимость, млрд руб: 75.0% компаний
# 2025-04-24 18:57:10,731 - signal_generator - INFO -   2024 - Выручка, млрд руб: 75.0% компаний
# 2025-04-24 18:57:10,731 - signal_generator - INFO -   2024 - Див доход, ао, %: 81.2% компаний
# 2025-04-24 18:57:10,731 - signal_generator - INFO -   2024 - Дивиденды/прибыль, %: 81.2% компаний
# 2025-04-24 18:57:10,731 - signal_generator - INFO -   2024 - Долг, млрд руб: 68.8% компаний
# 2025-04-24 18:57:10,731 - signal_generator - INFO -   2024 - Долг/EBITDA: 68.8% компаний
# 2025-04-24 18:57:10,732 - signal_generator - INFO -   2024 - Доходность FCF, %: 75.0% компаний
# 2025-04-24 18:57:10,732 - signal_generator - INFO -   2024 - Капитализация, млрд руб: 81.2% компаний
# 2025-04-24 18:57:10,732 - signal_generator - INFO -   2024 - Наличность, млрд руб: 75.0% компаний
# 2025-04-24 18:57:10,732 - signal_generator - INFO -   2024 - Опер. расходы, млрд руб: 81.2% компаний
# 2025-04-24 18:57:10,733 - signal_generator - INFO -   2024 - Опер.денежный поток, млрд руб: 75.0% компаний
# 2025-04-24 18:57:10,733 - signal_generator - INFO -   2024 - Операционная прибыль, млрд руб: 75.0% компаний
# 2025-04-24 18:57:10,733 - signal_generator - INFO -   2024 - Рентаб EBITDA, %: 75.0% компаний
# 2025-04-24 18:57:10,733 - signal_generator - INFO -   2024 - Цена акции ао, руб: 81.2% компаний
# 2025-04-24 18:57:10,733 - signal_generator - INFO -   2024 - Число акций ао, млн: 81.2% компаний
# 2025-04-24 18:57:10,734 - signal_generator - INFO -   2024 - Чистая прибыль, млрд руб: 81.2% компаний
# 2025-04-24 18:57:10,734 - signal_generator - INFO -   2024 - Чистая рентаб, %: 75.0% компаний
# 2025-04-24 18:57:10,734 - signal_generator - INFO -   2024 - Чистые активы, млрд руб: 75.0% компаний
# 2025-04-24 18:57:10,734 - signal_generator - INFO -   2024 - Чистый долг, млрд руб: 68.8% компаний
# 2025-04-24 18:57:10,946 - signal_generator - INFO - Фундаментальные скоры по тикерам:
# 2025-04-24 18:57:10,946 - signal_generator - INFO -   AFKS: 2024: -0.294
# 2025-04-24 18:57:10,946 - signal_generator - INFO -   ALRS: 2024: -0.183
# 2025-04-24 18:57:10,947 - signal_generator - INFO -   GAZP: 2024: 0.000
# 2025-04-24 18:57:10,947 - signal_generator - INFO -   GMKN: 2024: -0.135
# 2025-04-24 18:57:10,947 - signal_generator - INFO -   LKOH: 2024: 0.362
# 2025-04-24 18:57:10,947 - signal_generator - INFO -   MAGN: 2024: -0.113
# 2025-04-24 18:57:10,948 - signal_generator - INFO -   MTSS: 2024: -0.222
# 2025-04-24 18:57:10,948 - signal_generator - INFO -   MVID: 2024: 0.000
# 2025-04-24 18:57:10,948 - signal_generator - INFO -   NVTK: 2024: 0.126
# 2025-04-24 18:57:10,949 - signal_generator - INFO -   PHOR: 2024: 0.089
# 2025-04-24 18:57:10,949 - signal_generator - INFO -   ROSN: 2024: 0.230
# 2025-04-24 18:57:10,949 - signal_generator - INFO -   RUAL: 2024: -0.222
# 2025-04-24 18:57:10,949 - signal_generator - INFO -   SBER: 2024: 0.151
# 2025-04-24 18:57:10,950 - signal_generator - INFO -   SIBN: 2024: 0.072
# 2025-04-24 18:57:10,950 - signal_generator - INFO -   SNGS: 2024: 0.000
# 2025-04-24 18:57:10,950 - signal_generator - INFO -   TATN: 2024: 0.145
# 2025-04-24 18:57:10,951 - signal_generator - INFO - Композитный скор рассчитан
# 2025-04-24 18:57:10,955 - signal_generator - INFO - Сгенерировано сигналов: Buy - 151, Hold - 1423, Sell - 74
# 2025-04-24 18:57:11,032 - signal_generator - INFO - Создан shortlist из 1648 записей (топ 30.0%)
# 2025-04-24 18:57:11,035 - signal_generator - INFO - Шортлист сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/shortlists/shortlist_20250414.csv
# 2025-04-24 18:57:11,036 - signal_generator - INFO - Актуальный шортлист сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/results.csv
# 2025-04-24 18:57:11,036 - signal_generator - INFO - Визуализация графиков котировок с торговыми сигналами
# 2025-04-24 18:57:11,297 - signal_generator - INFO - График сигналов для AFKS сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/AFKS/signals.png
# 2025-04-24 18:57:11,559 - signal_generator - INFO - График сигналов для ALRS сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/ALRS/signals.png
# 2025-04-24 18:57:11,822 - signal_generator - INFO - График сигналов для GAZP сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/GAZP/signals.png
# 2025-04-24 18:57:12,092 - signal_generator - INFO - График сигналов для GMKN сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/GMKN/signals.png
# 2025-04-24 18:57:12,359 - signal_generator - INFO - График сигналов для LKOH сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/LKOH/signals.png
# 2025-04-24 18:57:12,620 - signal_generator - INFO - График сигналов для MAGN сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/MAGN/signals.png
# 2025-04-24 18:57:12,889 - signal_generator - INFO - График сигналов для MTSS сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/MTSS/signals.png
# 2025-04-24 18:57:13,145 - signal_generator - INFO - График сигналов для MVID сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/MVID/signals.png
# 2025-04-24 18:57:13,408 - signal_generator - INFO - График сигналов для NVTK сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/NVTK/signals.png
# 2025-04-24 18:57:13,681 - signal_generator - INFO - График сигналов для PHOR сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/PHOR/signals.png
# 2025-04-24 18:57:13,951 - signal_generator - INFO - График сигналов для ROSN сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/ROSN/signals.png
# 2025-04-24 18:57:14,260 - signal_generator - INFO - График сигналов для RUAL сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/RUAL/signals.png
# 2025-04-24 18:57:14,529 - signal_generator - INFO - График сигналов для SBER сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/SBER/signals.png
# 2025-04-24 18:57:14,803 - signal_generator - INFO - График сигналов для SIBN сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/SIBN/signals.png
# 2025-04-24 18:57:15,078 - signal_generator - INFO - График сигналов для SNGS сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/SNGS/signals.png
# 2025-04-24 18:57:15,342 - signal_generator - INFO - График сигналов для TATN сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/TATN/signals.png
# 2025-04-24 18:57:15,343 - signal_generator - INFO - Визуализация компонентов композитного скора
# 2025-04-24 18:57:15,806 - signal_generator - INFO - График скоров для AFKS сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/AFKS/scores.png
# 2025-04-24 18:57:16,263 - signal_generator - INFO - График скоров для ALRS сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/ALRS/scores.png
# 2025-04-24 18:57:16,738 - signal_generator - INFO - График скоров для GAZP сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/GAZP/scores.png
# 2025-04-24 18:57:17,203 - signal_generator - INFO - График скоров для GMKN сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/GMKN/scores.png
# 2025-04-24 18:57:17,667 - signal_generator - INFO - График скоров для LKOH сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/LKOH/scores.png
# 2025-04-24 18:57:18,123 - signal_generator - INFO - График скоров для MAGN сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/MAGN/scores.png
# 2025-04-24 18:57:18,584 - signal_generator - INFO - График скоров для MTSS сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/MTSS/scores.png
# 2025-04-24 18:57:19,039 - signal_generator - INFO - График скоров для MVID сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/MVID/scores.png
# 2025-04-24 18:57:19,616 - signal_generator - INFO - График скоров для NVTK сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/NVTK/scores.png
# 2025-04-24 18:57:20,083 - signal_generator - INFO - График скоров для PHOR сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/PHOR/scores.png
# 2025-04-24 18:57:20,546 - signal_generator - INFO - График скоров для ROSN сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/ROSN/scores.png
# 2025-04-24 18:57:21,004 - signal_generator - INFO - График скоров для RUAL сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/RUAL/scores.png
# 2025-04-24 18:57:21,470 - signal_generator - INFO - График скоров для SBER сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/SBER/scores.png
# 2025-04-24 18:57:22,006 - signal_generator - INFO - График скоров для SIBN сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/SIBN/scores.png
# 2025-04-24 18:57:22,496 - signal_generator - INFO - График скоров для SNGS сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/SNGS/scores.png
# 2025-04-24 18:57:22,979 - signal_generator - INFO - График скоров для TATN сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/TATN/scores.png
# 2025-04-24 18:57:23,274 - signal_generator - INFO - Исторические сигналы сохранены в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results/signals/signals_20250424.csv
# 2025-04-24 18:57:23,559 - signal_generator - INFO - Полные результаты сохранены в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_signals_20250424_185654.csv
# 2025-04-24 18:57:23,559 - signal_generator - INFO - Пайплайн выполнен за 12.95 секунд
# 2025-04-24 18:57:23,559 - signal_generator - INFO - Обработано 1648 строк данных
# 2025-04-24 18:57:23,560 - signal_generator - INFO - Обработано 16 тикеров
# 2025-04-24 18:57:23,560 - signal_generator - INFO - Создано сигналов: Buy - 151, Hold - 1423, Sell - 74
# 2025-04-24 18:57:23,561 - signal_generator - INFO - В шортлист включено 1648 записей
# 2025-04-24 18:57:23,561 - signal_generator - INFO - Все результаты сохранены в каталоге: /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_results
# 2025-04-24 18:57:23 - HonestBacktester - INFO - Запуск бэктеста на тестовых данных
# 2025-04-24 18:57:23,563 - backtester - INFO - Запуск пайплайна бэктестирования
# 2025-04-24 18:57:23,563 - backtester - INFO - Загрузка данных из /Users/aeshef/Documents/GitHub/kursach/data/signals.csv
# 2025-04-24 18:57:23,736 - backtester - INFO - Загружено 7471 строк данных
# 2025-04-24 18:57:23,742 - backtester - INFO - Период бэктеста: 2025-01-02 - 2025-04-14
# 2025-04-24 18:57:23,743 - backtester - INFO - Расчет доходностей по тикерам
# 2025-04-24 18:57:23,753 - backtester - INFO - Рассчитаны доходности для 16 тикеров
# 2025-04-24 18:57:23,754 - backtester - INFO - Расчет доходности портфеля с 17 весами
# 2025-04-24 18:57:23,754 - backtester - INFO - Анализ данных доходностей:
# 2025-04-24 18:57:23,755 - backtester - INFO - Тикер AFKS: 10/103 ненулевых точек, макс. значение: 0.063670
# 2025-04-24 18:57:23,755 - backtester - INFO - Добавлен тикер AFKS с весом 0.1400
# 2025-04-24 18:57:23,756 - backtester - INFO - Тикер ALRS: 3/103 ненулевых точек, макс. значение: 0.009601
# 2025-04-24 18:57:23,756 - backtester - INFO - Добавлен тикер ALRS с весом 0.0000
# 2025-04-24 18:57:23,757 - backtester - INFO - Тикер GAZP: 19/103 ненулевых точек, макс. значение: 0.081346
# 2025-04-24 18:57:23,757 - backtester - INFO - Добавлен тикер GAZP с весом 0.0000
# 2025-04-24 18:57:23,758 - backtester - INFO - Тикер GMKN: 5/103 ненулевых точек, макс. значение: 0.029989
# 2025-04-24 18:57:23,758 - backtester - INFO - Добавлен тикер GMKN с весом 0.0000
# 2025-04-24 18:57:23,758 - backtester - INFO - Тикер LKOH: 36/103 ненулевых точек, макс. значение: 0.035569
# 2025-04-24 18:57:23,759 - backtester - INFO - Добавлен тикер LKOH с весом 0.1400
# 2025-04-24 18:57:23,759 - backtester - INFO - Тикер MAGN: 7/103 ненулевых точек, макс. значение: 0.021883
# 2025-04-24 18:57:23,760 - backtester - INFO - Добавлен тикер MAGN с весом 0.0000
# 2025-04-24 18:57:23,760 - backtester - INFO - Тикер MTSS: 8/103 ненулевых точек, макс. значение: 0.058961
# 2025-04-24 18:57:23,760 - backtester - INFO - Добавлен тикер MTSS с весом 0.0000
# 2025-04-24 18:57:23,761 - backtester - INFO - Тикер MVID: 10/103 ненулевых точек, макс. значение: 0.073958
# 2025-04-24 18:57:23,761 - backtester - INFO - Добавлен тикер MVID с весом 0.0000
# 2025-04-24 18:57:23,761 - backtester - INFO - Тикер NVTK: 30/103 ненулевых точек, макс. значение: 0.093680
# 2025-04-24 18:57:23,762 - backtester - INFO - Добавлен тикер NVTK с весом 0.0000
# 2025-04-24 18:57:23,762 - backtester - INFO - Тикер PHOR: 25/103 ненулевых точек, макс. значение: 0.050749
# 2025-04-24 18:57:23,763 - backtester - INFO - Добавлен тикер PHOR с весом 0.0000
# 2025-04-24 18:57:23,763 - backtester - INFO - Тикер ROSN: 23/103 ненулевых точек, макс. значение: 0.072277
# 2025-04-24 18:57:23,763 - backtester - INFO - Добавлен тикер ROSN с весом 0.0000
# 2025-04-24 18:57:23,764 - backtester - INFO - Тикер RUAL: 10/103 ненулевых точек, макс. значение: 0.060226
# 2025-04-24 18:57:23,764 - backtester - INFO - Добавлен тикер RUAL с весом 0.1400
# 2025-04-24 18:57:23,764 - backtester - INFO - Тикер SBER: 10/103 ненулевых точек, макс. значение: 0.067809
# 2025-04-24 18:57:23,765 - backtester - INFO - Добавлен тикер SBER с весом 0.1400
# 2025-04-24 18:57:23,765 - backtester - INFO - Тикер SIBN: 21/103 ненулевых точек, макс. значение: 0.067986
# 2025-04-24 18:57:23,765 - backtester - INFO - Добавлен тикер SIBN с весом 0.0000
# 2025-04-24 18:57:23,766 - backtester - INFO - Тикер SNGS: 13/103 ненулевых точек, макс. значение: 0.031250
# 2025-04-24 18:57:23,766 - backtester - INFO - Добавлен тикер SNGS с весом 0.0000
# 2025-04-24 18:57:23,767 - backtester - INFO - Тикер TATN: 24/103 ненулевых точек, макс. значение: 0.053434
# 2025-04-24 18:57:23,767 - backtester - INFO - Добавлен тикер TATN с весом 0.1400
# 2025-04-24 18:57:23,768 - backtester - INFO - Добавлена безрисковая часть с весом 30.0% и ставкой 7.50%
# 2025-04-24 18:57:23,768 - backtester - INFO - Расчет метрик эффективности
# 2025-04-24 18:57:23,769 - backtester - INFO - Кумулятивная доходность: -1.08%, Годовая доходность: -2.62%, Шарп: -2.32, Макс. просадка: -2.36%
# 2025-04-24 18:57:23,770 - backtester - INFO - Создание визуализации результатов бэктеста
# 2025-04-24 18:57:23,840 - backtester - INFO - График кумулятивной доходности сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_backtest/cumulative_return.png
# 2025-04-24 18:57:23,898 - backtester - INFO - График просадок сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_backtest/drawdown.png
# 2025-04-24 18:57:23,900 - backtester - INFO - Метрики и данные сохранены в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/test_backtest
# 2025-04-24 18:57:23 - HonestBacktester - INFO - Запуск бэктеста на тренировочных данных для сравнения
# 2025-04-24 18:57:23,901 - backtester - INFO - Запуск пайплайна бэктестирования
# 2025-04-24 18:57:23,902 - backtester - INFO - Загрузка данных из /Users/aeshef/Documents/GitHub/kursach/data/signals.csv
# 2025-04-24 18:57:24,062 - backtester - INFO - Загружено 7471 строк данных
# 2025-04-24 18:57:24,077 - backtester - INFO - Период бэктеста: 2024-01-02 - 2024-12-31
# 2025-04-24 18:57:24,078 - backtester - INFO - Расчет доходностей по тикерам
# 2025-04-24 18:57:24,095 - backtester - INFO - Рассчитаны доходности для 16 тикеров
# 2025-04-24 18:57:24,096 - backtester - INFO - Расчет доходности портфеля с 17 весами
# 2025-04-24 18:57:24,096 - backtester - INFO - Анализ данных доходностей:
# 2025-04-24 18:57:24,096 - backtester - INFO - Тикер AFKS: 40/365 ненулевых точек, макс. значение: 0.072261
# 2025-04-24 18:57:24,097 - backtester - INFO - Добавлен тикер AFKS с весом 0.1400
# 2025-04-24 18:57:24,097 - backtester - INFO - Тикер ALRS: 26/365 ненулевых точек, макс. значение: 0.066044
# 2025-04-24 18:57:24,098 - backtester - INFO - Добавлен тикер ALRS с весом 0.0000
# 2025-04-24 18:57:24,098 - backtester - INFO - Тикер GAZP: 46/365 ненулевых точек, макс. значение: 0.071807
# 2025-04-24 18:57:24,098 - backtester - INFO - Добавлен тикер GAZP с весом 0.0000
# 2025-04-24 18:57:24,099 - backtester - INFO - Тикер GMKN: 19/359 ненулевых точек, макс. значение: 0.044227
# 2025-04-24 18:57:24,100 - backtester - INFO - Добавлен тикер GMKN с весом 0.0000
# 2025-04-24 18:57:24,100 - backtester - INFO - Тикер LKOH: 98/365 ненулевых точек, макс. значение: 0.072129
# 2025-04-24 18:57:24,101 - backtester - INFO - Добавлен тикер LKOH с весом 0.1400
# 2025-04-24 18:57:24,101 - backtester - INFO - Тикер MAGN: 35/363 ненулевых точек, макс. значение: 0.059012
# 2025-04-24 18:57:24,102 - backtester - INFO - Добавлен тикер MAGN с весом 0.0000
# 2025-04-24 18:57:24,102 - backtester - INFO - Тикер MTSS: 38/365 ненулевых точек, макс. значение: 0.040393
# 2025-04-24 18:57:24,102 - backtester - INFO - Добавлен тикер MTSS с весом 0.0000
# 2025-04-24 18:57:24,103 - backtester - INFO - Тикер MVID: 30/365 ненулевых точек, макс. значение: 0.130662
# 2025-04-24 18:57:24,103 - backtester - INFO - Добавлен тикер MVID с весом 0.0000
# 2025-04-24 18:57:24,103 - backtester - INFO - Тикер NVTK: 68/362 ненулевых точек, макс. значение: 0.045208
# 2025-04-24 18:57:24,104 - backtester - INFO - Добавлен тикер NVTK с весом 0.0000
# 2025-04-24 18:57:24,104 - backtester - INFO - Тикер PHOR: 79/365 ненулевых точек, макс. значение: 0.054028
# 2025-04-24 18:57:24,104 - backtester - INFO - Добавлен тикер PHOR с весом 0.0000
# 2025-04-24 18:57:24,105 - backtester - INFO - Тикер ROSN: 93/365 ненулевых точек, макс. значение: 0.099575
# 2025-04-24 18:57:24,105 - backtester - INFO - Добавлен тикер ROSN с весом 0.0000
# 2025-04-24 18:57:24,105 - backtester - INFO - Тикер RUAL: 34/365 ненулевых точек, макс. значение: 0.049258
# 2025-04-24 18:57:24,106 - backtester - INFO - Добавлен тикер RUAL с весом 0.1400
# 2025-04-24 18:57:24,106 - backtester - INFO - Тикер SBER: 50/365 ненулевых точек, макс. значение: 0.123624
# 2025-04-24 18:57:24,106 - backtester - INFO - Добавлен тикер SBER с весом 0.1400
# 2025-04-24 18:57:24,107 - backtester - INFO - Тикер SIBN: 69/361 ненулевых точек, макс. значение: 0.030878
# 2025-04-24 18:57:24,107 - backtester - INFO - Добавлен тикер SIBN с весом 0.0000
# 2025-04-24 18:57:24,107 - backtester - INFO - Тикер SNGS: 39/365 ненулевых точек, макс. значение: 0.051565
# 2025-04-24 18:57:24,108 - backtester - INFO - Добавлен тикер SNGS с весом 0.0000
# 2025-04-24 18:57:24,108 - backtester - INFO - Тикер TATN: 86/363 ненулевых точек, макс. значение: 0.063841
# 2025-04-24 18:57:24,109 - backtester - INFO - Добавлен тикер TATN с весом 0.1400
# ...
# 2025-04-24 18:57:41,947 - backtester - INFO - Запуск пайплайна бэктестирования
# 2025-04-24 18:57:41,948 - backtester - INFO - Загрузка данных из /Users/aeshef/Documents/GitHub/kursach/data/signals.csv
# 2025-04-24 18:57:42,100 - backtester - INFO - Загружено 7471 строк данных
# 2025-04-24 18:57:42,109 - backtester - INFO - Период бэктеста: 2024-01-02 - 2025-04-14
# 2025-04-24 18:57:42,109 - backtester - INFO - Расчет доходностей по тикерам
# 2025-04-24 18:57:42,136 - backtester - INFO - Рассчитаны доходности для 16 тикеров
# 2025-04-24 18:57:42,137 - backtester - INFO - Расчет доходности портфеля с 17 весами
# 2025-04-24 18:57:42,137 - backtester - INFO - Анализ данных доходностей:
# 2025-04-24 18:57:42,138 - backtester - INFO - Тикер AFKS: 48/468 ненулевых точек, макс. значение: 0.072261
# 2025-04-24 18:57:42,139 - backtester - INFO - Добавлен тикер AFKS (LONG) с весом 0.1400
# 2025-04-24 18:57:42,139 - backtester - INFO - Тикер ALRS: 27/468 ненулевых точек, макс. значение: 0.066044
# 2025-04-24 18:57:42,139 - backtester - INFO - Добавлен тикер ALRS (LONG) с весом 0.0000
# 2025-04-24 18:57:42,140 - backtester - INFO - Тикер GAZP: 63/468 ненулевых точек, макс. значение: 0.081346
# 2025-04-24 18:57:42,140 - backtester - INFO - Добавлен тикер GAZP (LONG) с весом 0.0000
# 2025-04-24 18:57:42,141 - backtester - INFO - Тикер GMKN: 22/462 ненулевых точек, макс. значение: 0.044227
# 2025-04-24 18:57:42,141 - backtester - INFO - Добавлен тикер GMKN (LONG) с весом 0.0000
# 2025-04-24 18:57:42,142 - backtester - INFO - Тикер LKOH: 133/468 ненулевых точек, макс. значение: 0.072129
# 2025-04-24 18:57:42,142 - backtester - INFO - Добавлен тикер LKOH (LONG) с весом 0.0898
# 2025-04-24 18:57:42,143 - backtester - INFO - Тикер MAGN: 40/466 ненулевых точек, макс. значение: 0.059012
# 2025-04-24 18:57:42,143 - backtester - INFO - Добавлен тикер MAGN (LONG) с весом 0.0000
# 2025-04-24 18:57:42,144 - backtester - INFO - Тикер MTSS: 44/468 ненулевых точек, макс. значение: 0.058961
# 2025-04-24 18:57:42,144 - backtester - INFO - Добавлен тикер MTSS (LONG) с весом 0.0000
# 2025-04-24 18:57:42,144 - backtester - INFO - Тикер MVID: 38/468 ненулевых точек, макс. значение: 0.130662
# 2025-04-24 18:57:42,145 - backtester - INFO - Добавлен тикер MVID (LONG) с весом 0.0000
# 2025-04-24 18:57:42,145 - backtester - INFO - Тикер NVTK: 96/465 ненулевых точек, макс. значение: 0.093680
# 2025-04-24 18:57:42,146 - backtester - INFO - Добавлен тикер NVTK (SHORT) с весом 0.1400
# 2025-04-24 18:57:42,146 - backtester - INFO - Тикер PHOR: 103/468 ненулевых точек, макс. значение: 0.054028
# 2025-04-24 18:57:42,147 - backtester - INFO - Добавлен тикер PHOR (SHORT) с весом 0.0000
# 2025-04-24 18:57:42,147 - backtester - INFO - Тикер ROSN: 114/468 ненулевых точек, макс. значение: 0.099575
# 2025-04-24 18:57:42,147 - backtester - INFO - Добавлен тикер ROSN (SHORT) с весом 0.1400
# 2025-04-24 18:57:42,148 - backtester - INFO - Тикер RUAL: 42/468 ненулевых точек, макс. значение: 0.060226
# 2025-04-24 18:57:42,148 - backtester - INFO - Добавлен тикер RUAL (SHORT) с весом 0.0000
# 2025-04-24 18:57:42,149 - backtester - INFO - Тикер SBER: 58/468 ненулевых точек, макс. значение: 0.123624
# 2025-04-24 18:57:42,149 - backtester - INFO - Добавлен тикер SBER (SHORT) с весом 0.0000
# 2025-04-24 18:57:42,150 - backtester - INFO - Тикер SIBN: 88/464 ненулевых точек, макс. значение: 0.067986
# 2025-04-24 18:57:42,150 - backtester - INFO - Добавлен тикер SIBN (SHORT) с весом 0.1400
# 2025-04-24 18:57:42,151 - backtester - INFO - Тикер SNGS: 50/468 ненулевых точек, макс. значение: 0.051565
# 2025-04-24 18:57:42,151 - backtester - INFO - Добавлен тикер SNGS (SHORT) с весом 0.0502
# 2025-04-24 18:57:42,151 - backtester - INFO - Тикер TATN: 109/466 ненулевых точек, макс. значение: 0.063841
# 2025-04-24 18:57:42,152 - backtester - INFO - Добавлен тикер TATN (SHORT) с весом 0.0000
# 2025-04-24 18:57:42,153 - backtester - INFO - Добавлена безрисковая часть с весом 30.0% и ставкой 7.50%
# 2025-04-24 18:57:42,154 - backtester - INFO - Расчет метрик эффективности
# 2025-04-24 18:57:42,154 - backtester - INFO - Кумулятивная доходность: 3.31%, Годовая доходность: 1.77%, Шарп: -1.79, Макс. просадка: -5.79%
# 2025-04-24 18:57:42,155 - backtester - INFO - Создание визуализации результатов бэктеста
# 2025-04-24 18:57:42,224 - backtester - INFO - График кумулятивной доходности сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/short_selling/backtest/cumulative_return.png
# 2025-04-24 18:57:42,284 - backtester - INFO - График просадок сохранен в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/short_selling/backtest/drawdown.png
# 2025-04-24 18:57:42,289 - backtester - INFO - Метрики и данные сохранены в /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/short_selling/backtest
# Улучшенный пайплайн завершен. Результаты сохранены в: /Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline
# {'honest_backtest': {'report': {'train_period': ('2024-01-01', '2024-12-31'),
#    'test_period': ('2025-01-01', '2025-06-30'),
#    'train_metrics': {'cumulative_return': -0.00035078561098655925,
#     'annual_return': -0.0002421993827024238,
#     'annual_volatility': 0.027131517605795647,
#     'sharpe_ratio': -2.7732396129079673,
#     'max_drawdown': -0.030769106629185305,
#     'win_rate': 0.7643835616438356},
#    'test_metrics': {'cumulative_return': -0.010773339114592329,
#     'annual_return': -0.026153010532335874,
#     'annual_volatility': 0.043676968997578156,
#     'sharpe_ratio': -2.3159347558651495,
#     'max_drawdown': -0.023568231415480922,
#     'win_rate': 0.7087378640776699},
#    'used_params': {'signal_params': {'weight_tech': 0.5,
#      'weight_sentiment': 0.3,
#      'weight_fundamental': 0.2,
#      'threshold_buy': 0.5,
#      'threshold_sell': -0.5},
#     'portfolio_params': {'min_rf_allocation': 0.25, 'max_rf_allocation': 0.35},
#     'risk_free_rate': 0.075}},
#   'report_file': '/Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/honest_backtest/honest_backtest_report.md'},
#  'short_selling': {'results': {'signals':                open     high      low    close   volume   SMA_20      EMA_20  \
#    date
#    2024-01-02   16.303   16.321   16.192   16.299     3049    0.000   16.299000
#    2024-01-03   16.242   16.436   16.242   16.328    96469    0.000   16.301762
#    2024-01-04   16.330   16.414   16.215   16.414   132364    0.000   16.312451
#    2024-01-05   16.420   16.471   16.276   16.311    86332    0.000   16.312313
#    2024-01-06   16.340   16.350   16.243   16.316     2079    0.000   16.312664
#    ...             ...      ...      ...      ...      ...      ...         ...
#    2025-04-10  639.400  659.300  622.700  655.800  6860323  659.840  656.056163
#    2025-04-11  655.400  689.000  655.400  688.000  5138741  659.655  659.098433
#    2025-04-12  688.000  697.900  685.200  692.500   393671  659.545  662.279535
#    2025-04-13  692.100  697.000  692.000  695.600   125951  659.995  665.452912
#    2025-04-14  696.700  696.700  677.600  686.400  3147141  659.420  667.447873
#
#                       WMA     RSI_14   Stoch_%K  ...  sentiment_return_corr  \
#    date                                          ...
#    2024-01-02    0.000000   0.000000   0.000000  ...               0.000000
#    2024-01-03    0.000000   0.000000   0.000000  ...               0.000000
#    2024-01-04    0.000000   0.000000   0.000000  ...               0.000000
#    2024-01-05    0.000000   0.000000   0.000000  ...               0.000000
#    2024-01-06    0.000000   0.000000   0.000000  ...               0.000000
#    ...                ...        ...        ...  ...                    ...
#    2025-04-10  639.121905  47.754209  65.763324  ...               0.349038
#    2025-04-11  644.517143  55.737876  94.850949  ...               0.238817
#    2025-04-12  650.503810  56.732938  95.300261  ...               0.212924
#    2025-04-13  656.751429  57.442720  97.998259  ...               0.173619
#    2025-04-14  661.376190  54.581044  89.991297  ...              -0.059856
#
#                news_count_volatility  ticker  tech_score  sentiment_score  \
#    date
#    2024-01-02               0.000000    AFKS   -0.974183        -0.286896
#    2024-01-03               0.000000    AFKS   -0.974183        -0.286896
#    2024-01-04               0.000000    AFKS   -0.974183        -0.286896
#    2024-01-05               0.000000    AFKS   -0.974183        -0.286896
#    2024-01-06               0.000000    AFKS   -0.974183        -0.286896
#    ...                           ...     ...         ...              ...
#    2025-04-10               0.062117    TATN   -0.077690         0.676242
#    2025-04-11               0.000000    TATN    0.432514        -0.177712
#    2025-04-12               0.000000    TATN    0.483390        -0.177712
#    2025-04-13               0.000000    TATN    0.652670        -0.177712
#    2025-04-14               0.025384    TATN    0.725185         1.060297
#
#                fundamental_score  composite_score  signal  position_type  \
#    date
#    2024-01-02           0.081904        -0.556780      -1          Short
#    2024-01-03           0.081904        -0.556780      -1          Short
#    2024-01-04           0.081904        -0.556780      -1          Short
#    2024-01-05           0.081904        -0.556780      -1          Short
#    2024-01-06           0.160205        -0.541119      -1          Short
#    ...                       ...              ...     ...            ...
#    2025-04-10           0.145069         0.193041       0           Hold
#    2025-04-11           0.145069         0.191957       0           Hold
#    2025-04-12           0.145069         0.217395       1           Long
#    2025-04-13           0.145069         0.302035       1           Long
#    2025-04-14           0.145069         0.709695       1           Long
#
#                in_shortlist
#    date
#    2024-01-02          True
#    2024-01-03          True
#    2024-01-04          True
#    2024-01-05          True
#    2024-01-06          True
#    ...                  ...
#    2025-04-10          True
#    2025-04-11          True
#    2025-04-12          True
#    2025-04-13          True
#    2025-04-14          True
#
#    [7471 rows x 390 columns],
#    'portfolio': {'weights': {'AFKS_LONG': 0.13999999999957205,
#      'ALRS_LONG': 3.2106400066239732e-12,
#      'GAZP_LONG': 1.4237224762666092e-10,
#      'GMKN_LONG': 3.2107736062619028e-12,
#      'LKOH_LONG': 0.08981789751425362,
#      'MAGN_LONG': 4.480826676573277e-12,
#      'MTSS_LONG': 0.0,
#      'MVID_LONG': 7.52364567937331e-12,
#      'NVTK_SHORT': 0.13999999972232102,
#      'PHOR_SHORT': 6.927015683460508e-10,
#      'ROSN_SHORT': 0.13999999987259543,
#      'RUAL_SHORT': 0.0,
#      'SBER_SHORT': 4.499682670429379e-13,
#      'SIBN_SHORT': 0.13999999999472287,
#      'SNGS_SHORT': 0.05018210232088004,
#      'TATN_SHORT': 0.0,
#      'RISK_FREE': 0.3},
#     'expected_return': 0.09014361444165814,
#     'expected_volatility': 0.06907758008296169,
#     'sharpe_ratio': 0.21922618631791643,
#     'risk_free_rate': 0.075,
#     'rf_allocation': 0.3},
#    'backtest': {'metrics': {'cumulative_return': 0.03310154588299241,
#      'annual_return': 0.017689907658180903,
#      'annual_volatility': 0.03196911986699529,
#      'sharpe_ratio': -1.7926703199916885,
#      'max_drawdown': -0.05794673338882883,
#      'win_rate': 0.7393162393162394},
#     'returns':                 AFKS          ALRS          GAZP          GMKN      LKOH  \
#     date
#     2024-01-02  0.000000  0.000000e+00  0.000000e+00  0.000000e+00  0.000000
#     2024-01-03 -0.000249 -9.088467e-14 -9.320460e-13 -2.492652e-14 -0.000907
#     2024-01-04 -0.000737 -9.018652e-16  1.675590e-13  1.177833e-14  0.000429
#     2024-01-05  0.000879 -1.127015e-14 -6.092208e-13  3.152453e-15 -0.000119
#     2024-01-06 -0.000043  2.695374e-15  7.912500e-14  2.761108e-15 -0.000020
#     ...              ...           ...           ...           ...       ...
#     2025-04-10  0.000000  0.000000e+00  0.000000e+00  0.000000e+00  0.001815
#     2025-04-11  0.000000  0.000000e+00  0.000000e+00 -9.628942e-14  0.000000
#     2025-04-12  0.000000  0.000000e+00  0.000000e+00  0.000000e+00 -0.000855
#     2025-04-13  0.000000  0.000000e+00  0.000000e+00  0.000000e+00  0.000000
#     2025-04-14  0.000000  0.000000e+00  0.000000e+00  0.000000e+00  0.000000
#
#                         MAGN  MTSS          MVID      NVTK          PHOR  \
#     date
#     2024-01-02  0.000000e+00   0.0  0.000000e+00 -0.000000 -0.000000e+00
#     2024-01-03 -7.074081e-14  -0.0 -1.832800e-13  0.001179  7.142336e-12
#     2024-01-04 -2.845104e-14  -0.0 -2.549630e-13 -0.000490 -1.455474e-12
#     2024-01-05  8.017300e-15  -0.0  6.489631e-14  0.000076  1.666901e-12
#     2024-01-06  1.141343e-14   0.0 -3.054845e-14  0.000019  2.390418e-12
#     ...                  ...   ...           ...       ...           ...
#     2025-04-10  0.000000e+00   0.0  0.000000e+00 -0.000000 -0.000000e+00
#     2025-04-11  0.000000e+00   0.0  0.000000e+00 -0.000000 -0.000000e+00
#     2025-04-12  0.000000e+00   0.0  0.000000e+00 -0.000000 -0.000000e+00
#     2025-04-13  0.000000e+00   0.0  0.000000e+00 -0.000000 -0.000000e+00
#     2025-04-14  0.000000e+00   0.0  0.000000e+00 -0.000000 -0.000000e+00
#
#                     ROSN  RUAL          SBER      SIBN      SNGS  TATN  \
#     date
#     2024-01-02 -0.000000  -0.0 -0.000000e+00 -0.000000 -0.000000  -0.0
#     2024-01-03  0.001251   0.0  6.180335e-15  0.000505  0.000837   0.0
#     2024-01-04 -0.000661   0.0 -7.211030e-16 -0.000759  0.000293   0.0
#     2024-01-05  0.000675  -0.0 -8.207505e-16 -0.000149  0.000136  -0.0
#     2024-01-06  0.000556   0.0  4.440152e-16 -0.000042  0.000163   NaN
#     ...              ...   ...           ...       ...       ...   ...
#     2025-04-10  0.002511  -0.0  1.441616e-15  0.001136 -0.000000  -0.0
#     2025-04-11 -0.000000   0.0 -0.000000e+00 -0.000000 -0.000000  -0.0
#     2025-04-12 -0.000000  -0.0 -0.000000e+00 -0.000000 -0.000000  -0.0
#     2025-04-13 -0.000000  -0.0 -0.000000e+00 -0.000000 -0.000000  -0.0
#     2025-04-14 -0.000000  -0.0 -0.000000e+00 -0.000000 -0.000000  -0.0
#
#                 portfolio_return  risk_free_return
#     date
#     2024-01-02          0.000086          0.000287
#     2024-01-03          0.001918          0.000287
#     2024-01-04         -0.001262          0.000287
#     2024-01-05          0.001134          0.000287
#     2024-01-06          0.000530          0.000287
#     ...                      ...               ...
#     2025-04-10          0.003910          0.000287
#     2025-04-11          0.000086          0.000287
#     2025-04-12         -0.000513          0.000287
#     2025-04-13          0.000086          0.000287
#     2025-04-14          0.000086          0.000287
#
#     [468 rows x 18 columns],
#     'cumulative_returns': date
#     2024-01-02    1.000086
#     2024-01-03    1.002004
#     2024-01-04    1.000739
#     2024-01-05    1.001874
#     2024-01-06    1.002405
#                     ...
#     2025-04-10    1.033364
#     2025-04-11    1.033453
#     2025-04-12    1.032924
#     2025-04-13    1.033013
#     2025-04-14    1.033102
#     Name: portfolio_return, Length: 468, dtype: float64}},
#   'results_dir': '/Users/aeshef/Documents/GitHub/kursach/data/improved_pipeline/short_selling'}}
